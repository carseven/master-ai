# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga de los datos en un dataframe del paquete Pandas

USA_Housing = "housing_train.csv"

df=pd.read_csv(USA_Housing)

# %%
#Descripción de los datos

print('This data gives different sales prices with respect to type of houses in USA:')

#Comprobamos si el dataframe empieza y acaba igual

print(df.head())
print(df.tail())

#Resumen
print(df.info())
# Out:
# This data gives different sales prices with respect to type of houses in USA:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# ...

# %%
#Creamos un objeto con los nombres de las columnas

headings = df.columns
print(headings)

#Averiguamos el tipo de dato de cada columna
tipos = df.dtypes
print(tipos)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Analizamos cuantitativamente (tenemos una lista SOLO con las columnas numéricas y sus estadísticos)

anlsCuant=df.describe(include=[np.number])
anlsCuant
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Describimos cualitativamente (lista con las variables cualitativas, con datos como la moda y la frecuencia)
anlsCual=df.describe(include=[object]) 
anlsCual
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
#Creamos la matriz de correlación

mcor=df.corr('pearson',1)
mcor
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
#Gráficamente usando el paquete Seaborn:
sns.heatmap(mcor, annot = True)
plt.show()

# %%
#Vamos a rellenar la diagonal con valores NaN para que no aparezcan las autocorrelaciones:
np.fill_diagonal(mcor.values,np.nan)

#Paso la matriz a una serie, para luego ordenarla:

mcor_s = mcor.unstack()
print(mcor_s)
print('---------------------------------------------')

#Ordenamos

ordenados = mcor_s.sort_values()
print(ordenados)
# Out:
# Id         Id                  NaN
#            MSSubClass     0.011156
#            LotFrontage   -0.010601
#            LotArea       -0.033226
#            OverallQual   -0.028365
#                             ...
# SalePrice  PoolArea       0.092404
#            MiscVal       -0.021190
#            MoSold         0.046432
#            YrSold        -0.028923
#            SalePrice           NaN
# Length: 1444, dtype: float64
# ---------------------------------------------
# BsmtFinSF1    BsmtUnfSF       -0.495251
# BsmtUnfSF     BsmtFinSF1      -0.495251
# BsmtFullBath  BsmtUnfSF       -0.422900
# BsmtUnfSF     BsmtFullBath    -0.422900
# YearBuilt     EnclosedPorch   -0.387268
#                                  ...
# PoolArea      PoolArea              NaN
# MiscVal       MiscVal               NaN
# MoSold        MoSold                NaN
# YrSold        YrSold                NaN
# SalePrice     SalePrice             NaN
# Length: 1444, dtype: float64

# %%
#Seleccionamos los que tengan una fuerte correlación (>75%):

corr_fuerte = ordenados[abs(ordenados)>0.75]
corr_fuerte
# Out:
# SalePrice     OverallQual     0.790982
# OverallQual   SalePrice       0.790982
# 1stFlrSF      TotalBsmtSF     0.819530
# TotalBsmtSF   1stFlrSF        0.819530
# GrLivArea     TotRmsAbvGrd    0.825489
# TotRmsAbvGrd  GrLivArea       0.825489
# GarageYrBlt   YearBuilt       0.825667
# YearBuilt     GarageYrBlt     0.825667
# GarageCars    GarageArea      0.882475
# GarageArea    GarageCars      0.882475
# dtype: float64

# %%
#De entre todas las correlaciones altas, la que más me preocupa es la columna de OverallQual con el precio de venta
#que es lo que queremos predecir. Si entrenamos el modelo con esa fuerte relación entre ambas, podría ser que a la hora de
#clasificar una casa sin esa variable, no diera buenos resultados. Por eso la voy a eliminar.

del df['OverallQual']

# %%
#Buscamos qué variables tienen valores faltantes, y además, 
#eliminaremos aquellas cuyos valores faltantes superen el 10% del total de datos

print(df.info())

#Me quedo con las columnas que, como mínimo, tengan el 90% del total de datos no nulos
df1=df.dropna(axis='columns',thresh=1314) 

#Vamos a ver cómo han quedado el resto de variables y cuáles tienen datos faltantes

print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Vamos a reemplazar los valores NaN de las variables relacionadas con el garaje con la categoría none.
#con el df1.info() anterior, vemos que estas variables son las de ID 56 a 63.


#df1[['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond']].fillna(value=36,inplace=True)
df1.iloc[:,54:61] = df1.iloc[:,54:61].fillna('None')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallCond    1460 non-null   int64
#  16  YearBuilt      1460 non-null   int64
# ...

# %%
#Nos fijamos en la variable MasVnrArea, que es el area de revestimiento de mampostería en pies cuadrados

print('DESCRIPCIÓN: \n',df1['MasVnrArea'].describe(),"\n")
print("LA MODA ES: ", df1['MasVnrArea'].mode(), "\n")
print("VALORES NULOS: ", df1['MasVnrArea'].isna().sum(),"\n")
print("FRECUENCIA DE LOS VALORES: \n", df1.MasVnrArea.value_counts(),'\n')
# Out:
# DESCRIPCIÓN:
#  count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64
#
# LA MODA ES:  0    0.0
# dtype: float64
#
# VALORES NULOS:  8
#
# FRECUENCIA DE LOS VALORES:
#  0.0      861
# 72.0       8
# 180.0      8
# 108.0      8
# 120.0      7
#         ...
# 651.0      1
# 337.0      1
# 415.0      1
# 293.0      1
# 621.0      1
# Name: MasVnrArea, Length: 327, dtype: int64

# %%
#Como vemos, la moda de la variable es el 0, con 861 veces en 1460 registros, más del 50%. Por tanto,
#decido reemplazar los valores nulos con la moda, que es el 0:

df1.MasVnrArea = df1.MasVnrArea.fillna(df1.MasVnrArea.mode()[0])
print ('VALORES NULOS: \n',df1['MasVnrArea'].isna().sum())
# Out:
# VALORES NULOS:
#  0
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
#Vamos a elegir dos variables categóricas más: BsmtExposure (paredes del sótano a nivel de calle o de jardín)
#y Electrical (sistema eléctrico):

print('DESCRIPCIÓN BsmtExposure: \n',df1['BsmtExposure'].describe(),'\n')
print('CATEGORÍAS BsmtExposure: \n',df1['BsmtExposure'].value_counts(),'\n')

print('DESCRIPCIÓN Electrical: \n',df1['Electrical'].describe(),'\n')
print('CATEGORÍAS Electrical: \n',df1['Electrical'].value_counts(),'\n')

#Como ambas modas tienen la frecuencia muy alta, 953 de 1422 en BsmtExposure y 1334 de 1459 en Electrictal, voy a rellenar 
#los valores nulos con la moda:

df1.BsmtExposure = df1.BsmtExposure.fillna(df1.BsmtExposure.mode()[0])
print ('VALORES NULOS BsmtExposure: \n',df1['BsmtExposure'].isna().sum())

df1.Electrical = df1.Electrical.fillna(df1.Electrical.mode()[0])
print ('VALORES NULOS Electrical: \n',df1['Electrical'].isna().sum())
# Out:
# DESCRIPCIÓN BsmtExposure:
#  count     1422
# unique       4
# top         No
# freq       953
# Name: BsmtExposure, dtype: object
#
# CATEGORÍAS BsmtExposure:
#  No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
#
# DESCRIPCIÓN Electrical:
#  count      1459
# unique        5
# top       SBrkr
# freq       1334
# Name: Electrical, dtype: object
#
# CATEGORÍAS Electrical:
#  SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
#
# VALORES NULOS BsmtExposure:
#  0
# VALORES NULOS Electrical:
#  0

# %%
#Rellenamos los valores nulos del resto de variables tal y como indica el enunciado, numéricas con '0' 
#y categóricas con la moda:

for col in df1:
    #averiguamos el dtype de cada columna:
    
    dt = df1[col].dtype 
    
    #Comprobamos si es un numérica o categórica:
    
    if dt == int or dt == float:
        df1[col]=df1[col].fillna(0)
    elif dt==object:
        df1[col]=df1[col].fillna(df1[col].mode()[0])
        
#Por último, verificamos que todos los nulos han sido tratados, y el conjunto de datos está listo para procesar:

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallCond    1460 non-null   int64
#  16  YearBuilt      1460 non-null   int64
# ...

# %%
## PROBLEMA DE REGRESIÓN
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

#cargamos los datos en dos variables, datos completos en x y variable a predecir en y
x = df1
y = df1.SalePrice

#separamos en conjunto de entrenamiento y test. Además, convertimos las categorías de las variables categóricas en nuevas variables, en este caso, numéricas,
#ya que scikit no acepta variables categóricas para los árboles de regresión

x_train, x_test, y_train, y_test = train_test_split(pd.get_dummies(x),y,test_size=0.2, random_state=42)

#creamos el árbol
arbol = DecisionTreeRegressor(random_state=42)

#buscamos los mejores parámetros para el árbol:.
arbol_params = {'max_depth':np.arange(1,50,2),'min_samples_leaf':np.arange(2,15)}

from sklearn.model_selection import GridSearchCV

#especificamos el número de divisiones que realizará la comprobación k-fold, en este caso, hemos elegido k=10
gs_arbol = GridSearchCV(arbol,arbol_params,cv=10)
gs_arbol.fit(x_train,y_train)
bp = gs_arbol.best_params_
print (bp)
# Out:
# {'max_depth': 9, 'min_samples_leaf': 2}

# %%
#entrenamos el árbol con los parámetros:

mejorArbol = DecisionTreeRegressor(max_depth=9, min_samples_leaf=2,random_state=42)
modelo = mejorArbol.fit(x_train,y_train)

#graficamos

fig = plt.figure(figsize=(50,50))
_ = tree.plot_tree(modelo,filled=True,feature_names=x_train.columns)

#como podemos observar, es un modeo muy grande, vamos a fijarnos con una profundidad de 2:

fig = plt.figure(figsize=(50,50))
_ = tree.plot_tree(modelo,filled=True, max_depth=2, feature_names=x_train.columns)

# %%
#vamos a predecir la variable target:
y_pred=modelo.predict(x_test)

#y comprobamos el error cometido con el estimador MSE (Mean Squared Error)
from sklearn.metrics import mean_squared_error

print('MSE:',mean_squared_error(y_pred,y_test))
# Out:
# MSE: 25592634.993557625
